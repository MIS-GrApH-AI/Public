# %% [markdown]
# # Dealing with Time

# %% [markdown]
# ![Time tree](images/TimeTree_demo.png)

# %% [markdown]
# The [MIMIC III documentation](https://mimic.physionet.org/mimicdata/time/) describes all of the time fields. Some key points are:
# "Time in the database is stored with one of two suffixes: TIME and DATE. If a column has TIME as the suffix, e.g. CHARTTIME, then the data resolution is down to the minute. If the column has DATE as the suffix, e.g. CHARTDATE, then the data resolution is down to the day."

# %%
import pandas as pd

# %% [markdown]
# ### Obtain a list of all timestamp fields in the MIMIC-III data
# - Copy table of all data columns from https://mit-lcp.github.io/mimic-schema-spy/columns.byTable.html into a spreadsheet
# - Filter the "Type" column on timestamp and delete all other rows
# - Note that all timestamp columns have a size of 22 characters, suggesting that they likely have a uniform format across the database
# - Keep only the "Table" and "Column" columns and save to CSV

# %%
time_fields = pd.read_csv('MIMIC-III_timestamp_fields.csv')

# %%
time_fields.loc[:,'Table'] = time_fields.loc[:,'Table'].str.title()
time_fields.loc[:,'Column'] = time_fields.loc[:,'Column'].str.upper()
time_fields
# Out:
#                  Table        Column
# 0           Admissions     ADMITTIME
# 1           Admissions     DEATHTIME
# 2           Admissions     DISCHTIME
# 3           Admissions     EDOUTTIME
# 4           Admissions     EDREGTIME
# ..                 ...           ...
# 69  Procedureevents_Mv     STARTTIME
# 70  Procedureevents_Mv     STORETIME
# 71            Services  TRANSFERTIME
# 72           Transfers        INTIME
# 73           Transfers       OUTTIME
#
# [74 rows x 2 columns]

# %% [markdown]
# ### Initialize a connection to the neo4j database.

# %%
import getpass
password = getpass.getpass("\nPlease enter the Neo4j database password to continue \n")
# Out:
# Please enter the Neo4j database password to continue
#  ·······

# %%
from neo4j import GraphDatabase
driver=GraphDatabase.driver(uri="bolt://localhost:7687", auth=('neo4j',password))
session=driver.session()

# %% [markdown]
# ### MERGE all timestamps as relationships into the time tree

# %%
# Create the root node of the time tree
query = 'MERGE (t:Timetree {name:"Time Tree"})'
session.run(query)

# %%
# Create all the year, month, and day nodes with relationships

# Column name from MIMIC becomes relationship name.
# Each node contains the datetime informationa for all higher nodes in the tree (example: month nodes contain
# We iterate through all of the data fields that contain timestamp
# data to write cypher code, which is then passed to Neo4j using the
# apoc.periodic.iterate function.
gaps = 1
iteration = 1

while gaps > 0:

    count = 0
    for index, row in time_fields.iterrows():
        Label = row[0]
        prop = row[1]
        query = '''
    "MATCH (n:{Label})
    WHERE NOT (n)-[:{prop}]->(:Day) AND n.{prop} =~ '[0-9]{{4}}-[0-9]{{2}}-[0-9]{{2}} [0-9]{{2}}:[0-9]{{2}}:[0-9]{{2}}' 
    WITH apoc.date.parse(n.{prop}, 'ms', 'yyyy-MM-dd HH:mm:ss', 'America/New York') AS ms, n
    WITH datetime({{epochmillis: ms}}).year AS yr, datetime({{epochmillis: ms}}).month AS mo, datetime({{epochmillis: ms}}).day AS dt,
    ms, n
    RETURN yr, mo, dt, ms, n",
    "MATCH (t:Timetree {{name:'Time Tree'}})
    MERGE (t)<-[:OF]-(y:Year {{year:yr}})
    MERGE (y)<-[:OF]-(m:Month {{year:yr, month:mo}})
    MERGE (m)<-[:OF]-(d:Day {{year:yr, month:mo, day:dt}})
    MERGE (d)<-[:{prop} {{{prop}:datetime({{epochmillis: ms}})}}]-(n)"'''.format(Label=Label, prop=prop)
        count += 1
#         print(Label, prop, count)
        command = 'CALL apoc.periodic.iterate('+query+', {batchSize:1000, parallel: true, iterateList:true})'
        session.run(command)

    query = '''
    MATCH (n:Noteevents)
    WHERE NOT (n)-[:STORETIME]->(:Day) AND EXISTS(n.STORETIME)
    RETURN count(n) AS gaps'''
    data = session.run(query)
    for node in data:
        gaps = node.get('gaps')
        print ('Gaps: ',gaps, 'Iteration: ',iteration)
    iteration =+ 1

# Print a test query 
# print(command)
# Out:
# Gaps:  376405 Iteration:  1
# Gaps:  280405 Iteration:  1
# Gaps:  190405 Iteration:  1
# Gaps:  131405 Iteration:  1
# Gaps:  81405 Iteration:  1
# Gaps:  35001 Iteration:  1
# Gaps:  13001 Iteration:  1
# Gaps:  4001 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# Gaps:  1 Iteration:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-4db4d22be847> in <module>
#      30 #         print(Label, prop, count)
#      31         command = 'CALL apoc.periodic.iterate('+query+', {batchSize:1000, parallel: true, iterateList:true})'
# ---> 32         session.run(command)
#      33
#      34     query = '''
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/work/simple.py in run(self, query, parameters, **kwparameters)
#     215
#     216         self._autoResult = Result(cx, hydrant, self._config.fetch_size, self._result_closed)
# --> 217         self._autoResult._run(query, parameters, self._config.database, self._config.default_access_mode, self._bookmarks, **kwparameters)
#     218
#     219         return self._autoResult
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/work/result.py in _run(self, query, parameters, db, access_mode, bookmarks, **kwparameters)
#      99         self._pull()
#     100         self._connection.send_all()
# --> 101         self._attach()
#     102
#     103     def _pull(self):
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/work/result.py in _attach(self)
#     200         if self._closed is False:
#     201             while self._attached is False:
# --> 202                 self._connection.fetch_message()
#     203
#     204     def _buffer_all(self):
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/io/_bolt4.py in fetch_message(self)
#     332         # Receive exactly one message
#     333         try:
# --> 334             details, summary_signature, summary_metadata = next(self.inbox)
#     335         except (IOError, OSError) as error:
#     336             log.error("Failed to read data from connection "
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/io/_common.py in __next__(self)
#      77
#      78     def __next__(self):
# ---> 79         tag, fields = self.pop()
#      80         if tag == b"\x71":
#      81             return fields, None, None
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/io/_common.py in pop(self)
#      71
#      72     def pop(self):
# ---> 73         return next(self._messages)
#      74
#      75
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/io/_common.py in _yield_messages(self, sock)
#      51                 while chunk_size == 0:
#      52                     # Determine the chunk size and skip noop
# ---> 53                     buffer.receive(sock, 2)
#      54                     chunk_size = buffer.pop_u16()
#      55                     if chunk_size == 0:
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/neo4j/packstream.py in receive(self, sock, n_bytes)
#     603         view = memoryview(self.data)
#     604         while self.used < end:
# --> 605             n = sock.recv_into(view[self.used:end], end - self.used)
#     606             if n == 0:
#     607                 raise OSError("No data")
#
# KeyboardInterrupt:

# %%
# Check for variations in the date formats of various properties
for index, row in time_fields.iterrows():
    Label = row[0]
    prop = row[1]
    query = 'MATCH (n:{Label}) RETURN n.{prop} AS prop LIMIT 6'''.format(Label=Label, prop=prop)
    data = session.run(query)
    for node in data:
        print(node.get('prop'), Label, prop)
# Out:
# 2196-04-09 12:26:00 Admissions ADMITTIME
# 2153-09-03 07:15:00 Admissions ADMITTIME
# 2157-10-18 19:34:00 Admissions ADMITTIME
# 2139-06-06 16:14:00 Admissions ADMITTIME
# 2160-11-02 02:06:00 Admissions ADMITTIME
# 2126-05-06 15:16:00 Admissions ADMITTIME
# None Admissions DEATHTIME
# None Admissions DEATHTIME
# None Admissions DEATHTIME
# None Admissions DEATHTIME
# None Admissions DEATHTIME
# None Admissions DEATHTIME
# 2196-04-10 15:54:00 Admissions DISCHTIME
# 2153-09-08 19:10:00 Admissions DISCHTIME
# 2157-10-25 14:00:00 Admissions DISCHTIME
# 2139-06-09 12:48:00 Admissions DISCHTIME
# 2160-11-05 14:55:00 Admissions DISCHTIME
# 2126-05-13 15:00:00 Admissions DISCHTIME
# 2196-04-09 13:24:00 Admissions EDOUTTIME
# None Admissions EDOUTTIME
# None Admissions EDOUTTIME
# None Admissions EDOUTTIME
# 2160-11-02 04:27:00 Admissions EDOUTTIME
# None Admissions EDOUTTIME
# 2196-04-09 10:06:00 Admissions EDREGTIME
# None Admissions EDREGTIME
# None Admissions EDREGTIME
# None Admissions EDREGTIME
# 2160-11-02 01:01:00 Admissions EDREGTIME
# None Admissions EDREGTIME
# 2146-10-05 13:24:00 Callout ACKNOWLEDGETIME
# 2114-11-28 09:43:08 Callout ACKNOWLEDGETIME
# 2114-12-01 12:26:05 Callout ACKNOWLEDGETIME
# 2136-12-29 10:33:51 Callout ACKNOWLEDGETIME
# 2199-09-18 11:58:33 Callout ACKNOWLEDGETIME
# 2162-11-30 11:15:08 Callout ACKNOWLEDGETIME
# 2146-10-05 13:16:55 Callout CREATETIME
# 2114-11-28 08:31:39 Callout CREATETIME
# 2114-11-30 10:24:25 Callout CREATETIME
# 2136-12-29 08:45:42 Callout CREATETIME
# 2199-09-18 11:47:47 Callout CREATETIME
# 2162-11-30 10:58:55 Callout CREATETIME
# None Callout CURRENTRESERVATIONTIME
# None Callout CURRENTRESERVATIONTIME
# None Callout CURRENTRESERVATIONTIME
# None Callout CURRENTRESERVATIONTIME
# None Callout CURRENTRESERVATIONTIME
# None Callout CURRENTRESERVATIONTIME
# 2146-10-05 15:27:44 Callout FIRSTRESERVATIONTIME
# None Callout FIRSTRESERVATIONTIME
# None Callout FIRSTRESERVATIONTIME
# None Callout FIRSTRESERVATIONTIME
# None Callout FIRSTRESERVATIONTIME
# None Callout FIRSTRESERVATIONTIME
# 2146-10-05 18:55:22 Callout OUTCOMETIME
# 2114-11-28 12:10:02 Callout OUTCOMETIME
# 2114-12-01 21:55:05 Callout OUTCOMETIME
# 2136-12-29 18:10:02 Callout OUTCOMETIME
# 2199-09-18 15:10:02 Callout OUTCOMETIME
# 2162-11-30 18:31:05 Callout OUTCOMETIME
# 2146-10-05 13:16:55 Callout UPDATETIME
# 2114-11-28 09:42:08 Callout UPDATETIME
# 2114-12-01 09:06:18 Callout UPDATETIME
# 2136-12-29 10:17:16 Callout UPDATETIME
# 2199-09-18 11:47:47 Callout UPDATETIME
# 2162-11-30 18:31:05 Callout UPDATETIME
# CHARTTIME Chartevents CHARTTIME
# 2134-05-12 12:00:00 Chartevents CHARTTIME
# 2134-05-12 12:00:00 Chartevents CHARTTIME
# 2134-05-12 12:00:00 Chartevents CHARTTIME
# 2134-05-12 12:00:00 Chartevents CHARTTIME
# 2134-05-12 12:00:00 Chartevents CHARTTIME
# STORETIME Chartevents STORETIME
# 2134-05-12 13:56:00 Chartevents STORETIME
# 2134-05-12 13:56:00 Chartevents STORETIME
# 2134-05-12 12:18:00 Chartevents STORETIME
# 2134-05-12 12:19:00 Chartevents STORETIME
# 2134-05-12 12:19:00 Chartevents STORETIME
# CHARTDATE Cptevents CHARTDATE
# None Cptevents CHARTDATE
# None Cptevents CHARTDATE
# None Cptevents CHARTDATE
# None Cptevents CHARTDATE
# None Cptevents CHARTDATE
# CHARTTIME Datetimeevents CHARTTIME
# 2172-03-14 11:00:00 Datetimeevents CHARTTIME
# 2172-03-14 13:00:00 Datetimeevents CHARTTIME
# 2172-03-14 15:00:00 Datetimeevents CHARTTIME
# 2172-03-14 17:00:00 Datetimeevents CHARTTIME
# 2172-03-14 19:00:00 Datetimeevents CHARTTIME
# STORETIME Datetimeevents STORETIME
# 2172-03-14 11:52:00 Datetimeevents STORETIME
# 2172-03-14 12:36:00 Datetimeevents STORETIME
# 2172-03-14 15:10:00 Datetimeevents STORETIME
# 2172-03-14 17:01:00 Datetimeevents STORETIME
# 2172-03-14 19:29:00 Datetimeevents STORETIME
# VALUE Datetimeevents VALUE
# None Datetimeevents VALUE
# None Datetimeevents VALUE
# None Datetimeevents VALUE
# None Datetimeevents VALUE
# None Datetimeevents VALUE
# INTIME Icustays INTIME
# 2198-02-14 23:27:38 Icustays INTIME
# 2170-11-05 11:05:29 Icustays INTIME
# 2128-06-24 15:05:20 Icustays INTIME
# 2120-08-07 23:12:42 Icustays INTIME
# 2186-12-25 21:08:04 Icustays INTIME
# OUTTIME Icustays OUTTIME
# 2198-02-18 05:26:11 Icustays OUTTIME
# 2170-11-08 17:46:57 Icustays OUTTIME
# 2128-06-27 12:32:29 Icustays OUTTIME
# 2120-08-10 00:39:04 Icustays OUTTIME
# 2186-12-27 12:01:13 Icustays OUTTIME
# CHARTTIME Inputevents_Cv CHARTTIME
# 2193-09-11 09:00:00 Inputevents_Cv CHARTTIME
# 2193-09-11 12:00:00 Inputevents_Cv CHARTTIME
# 2193-09-11 16:00:00 Inputevents_Cv CHARTTIME
# 2193-09-11 19:00:00 Inputevents_Cv CHARTTIME
# 2193-09-11 21:00:00 Inputevents_Cv CHARTTIME
# STORETIME Inputevents_Cv STORETIME
# 2193-09-11 11:12:00 Inputevents_Cv STORETIME
# 2193-09-11 12:05:00 Inputevents_Cv STORETIME
# 2193-09-11 16:52:00 Inputevents_Cv STORETIME
# 2193-09-11 19:06:00 Inputevents_Cv STORETIME
# 2193-09-11 21:19:00 Inputevents_Cv STORETIME
# COMMENTS_DATE Inputevents_Mv COMMENTS_DATE
# 2133-02-05 12:52:00 Inputevents_Mv COMMENTS_DATE
# None Inputevents_Mv COMMENTS_DATE
# None Inputevents_Mv COMMENTS_DATE
# 2133-02-03 17:06:00 Inputevents_Mv COMMENTS_DATE
# 2133-02-03 17:06:00 Inputevents_Mv COMMENTS_DATE
# ENDTIME Inputevents_Mv ENDTIME
# 2133-02-05 08:45:00 Inputevents_Mv ENDTIME
# 2133-02-05 06:30:00 Inputevents_Mv ENDTIME
# 2133-02-05 06:30:00 Inputevents_Mv ENDTIME
# 2133-02-03 12:01:00 Inputevents_Mv ENDTIME
# 2133-02-03 12:01:00 Inputevents_Mv ENDTIME
# STARTTIME Inputevents_Mv STARTTIME
# 2133-02-05 06:29:00 Inputevents_Mv STARTTIME
# 2133-02-05 05:34:00 Inputevents_Mv STARTTIME
# 2133-02-05 05:34:00 Inputevents_Mv STARTTIME
# 2133-02-03 12:00:00 Inputevents_Mv STARTTIME
# 2133-02-03 12:00:00 Inputevents_Mv STARTTIME
# STORETIME Inputevents_Mv STORETIME
# 2133-02-05 06:27:00 Inputevents_Mv STORETIME
# 2133-02-05 12:57:00 Inputevents_Mv STORETIME
# 2133-02-05 12:57:00 Inputevents_Mv STORETIME
# 2133-02-03 13:21:00 Inputevents_Mv STORETIME
# 2133-02-03 13:21:00 Inputevents_Mv STORETIME
# CHARTTIME Labevents CHARTTIME
# 2101-10-12 16:07:00 Labevents CHARTTIME
# 2101-10-12 18:17:00 Labevents CHARTTIME
# 2101-10-12 18:17:00 Labevents CHARTTIME
# 2101-10-12 18:17:00 Labevents CHARTTIME
# 2101-10-12 18:17:00 Labevents CHARTTIME
# CHARTDATE Microbiologyevents CHARTDATE
# 2156-04-13 00:00:00 Microbiologyevents CHARTDATE
# 2156-04-20 00:00:00 Microbiologyevents CHARTDATE
# 2156-04-20 00:00:00 Microbiologyevents CHARTDATE
# 2156-04-20 00:00:00 Microbiologyevents CHARTDATE
# 2156-04-20 00:00:00 Microbiologyevents CHARTDATE
# CHARTTIME Microbiologyevents CHARTTIME
# 2156-04-13 14:18:00 Microbiologyevents CHARTTIME
# 2156-04-20 13:10:00 Microbiologyevents CHARTTIME
# 2156-04-20 16:00:00 Microbiologyevents CHARTTIME
# None Microbiologyevents CHARTTIME
# None Microbiologyevents CHARTTIME
# CHARTDATE Noteevents CHARTDATE
# 2151-08-04 Noteevents CHARTDATE
# 2118-06-14 Noteevents CHARTDATE
# 2119-05-25 Noteevents CHARTDATE
# 2124-08-18 Noteevents CHARTDATE
# 2162-03-25 Noteevents CHARTDATE
# CHARTTIME Noteevents CHARTTIME
# None Noteevents CHARTTIME
# None Noteevents CHARTTIME
# None Noteevents CHARTTIME
# None Noteevents CHARTTIME
# None Noteevents CHARTTIME
# STORETIME Noteevents STORETIME
# None Noteevents STORETIME
# None Noteevents STORETIME
# None Noteevents STORETIME
# None Noteevents STORETIME
# None Noteevents STORETIME
# CHARTTIME Outputevents CHARTTIME
# 2142-09-08 10:00:00 Outputevents CHARTTIME
# 2142-09-08 12:00:00 Outputevents CHARTTIME
# 2142-09-08 13:00:00 Outputevents CHARTTIME
# 2142-09-08 14:00:00 Outputevents CHARTTIME
# 2142-09-08 16:00:00 Outputevents CHARTTIME
# STORETIME Outputevents STORETIME
# 2142-09-08 12:08:00 Outputevents STORETIME
# 2142-09-08 12:08:00 Outputevents STORETIME
# 2142-09-08 13:39:00 Outputevents STORETIME
# 2142-09-08 16:17:00 Outputevents STORETIME
# 2142-09-08 16:17:00 Outputevents STORETIME
# DOB Patients DOB
# 2075-03-13 00:00:00 Patients DOB
# 2164-12-27 00:00:00 Patients DOB
# 2090-03-15 00:00:00 Patients DOB
# 2078-03-06 00:00:00 Patients DOB
# 2089-11-26 00:00:00 Patients DOB
# DOD Patients DOD
# None Patients DOD
# 2188-11-22 00:00:00 Patients DOD
# None Patients DOD
# None Patients DOD
# None Patients DOD
# DOD_HOSP Patients DOD_HOSP
# None Patients DOD_HOSP
# 2188-11-22 00:00:00 Patients DOD_HOSP
# None Patients DOD_HOSP
# None Patients DOD_HOSP
# None Patients DOD_HOSP
# DOD_SSN Patients DOD_SSN
# None Patients DOD_SSN
# None Patients DOD_SSN
# None Patients DOD_SSN
# None Patients DOD_SSN
# None Patients DOD_SSN
# ENDDATE Prescriptions ENDDATE
# 2175-06-12 00:00:00 Prescriptions ENDDATE
# 2175-06-12 00:00:00 Prescriptions ENDDATE
# 2175-06-12 00:00:00 Prescriptions ENDDATE
# 2175-06-12 00:00:00 Prescriptions ENDDATE
# 2175-06-12 00:00:00 Prescriptions ENDDATE
# STARTDATE Prescriptions STARTDATE
# 2175-06-11 00:00:00 Prescriptions STARTDATE
# 2175-06-11 00:00:00 Prescriptions STARTDATE
# 2175-06-11 00:00:00 Prescriptions STARTDATE
# 2175-06-11 00:00:00 Prescriptions STARTDATE
# 2175-06-11 00:00:00 Prescriptions STARTDATE
# COMMENTS_DATE Procedureevents_Mv COMMENTS_DATE
# None Procedureevents_Mv COMMENTS_DATE
# None Procedureevents_Mv COMMENTS_DATE
# None Procedureevents_Mv COMMENTS_DATE
# None Procedureevents_Mv COMMENTS_DATE
# None Procedureevents_Mv COMMENTS_DATE
# ENDTIME Procedureevents_Mv ENDTIME
# 2145-03-12 23:05:00 Procedureevents_Mv ENDTIME
# 2145-03-12 23:05:00 Procedureevents_Mv ENDTIME
# 2145-03-18 20:01:00 Procedureevents_Mv ENDTIME
# 2145-03-12 23:37:00 Procedureevents_Mv ENDTIME
# 2145-03-16 16:00:00 Procedureevents_Mv ENDTIME
# STARTTIME Procedureevents_Mv STARTTIME
# 2145-03-12 23:04:00 Procedureevents_Mv STARTTIME
# 2145-03-12 23:04:00 Procedureevents_Mv STARTTIME
# 2145-03-12 23:05:00 Procedureevents_Mv STARTTIME
# 2145-03-12 23:36:00 Procedureevents_Mv STARTTIME
# 2145-03-13 01:27:00 Procedureevents_Mv STARTTIME
# STORETIME Procedureevents_Mv STORETIME
# 2145-03-12 23:04:00 Procedureevents_Mv STORETIME
# 2145-03-12 23:04:00 Procedureevents_Mv STORETIME
# 2145-03-18 20:01:39 Procedureevents_Mv STORETIME
# 2145-03-12 23:36:00 Procedureevents_Mv STORETIME
# 2145-03-16 17:57:00 Procedureevents_Mv STORETIME
# TRANSFERTIME Services TRANSFERTIME
# 2122-07-22 14:07:27 Services TRANSFERTIME
# 2122-07-26 18:31:49 Services TRANSFERTIME
# 2172-09-28 19:22:15 Services TRANSFERTIME
# 2201-01-09 20:16:45 Services TRANSFERTIME
# 2181-03-23 08:24:41 Services TRANSFERTIME
# INTIME Transfers INTIME
# 2142-04-29 15:27:11 Transfers INTIME
# 2142-05-04 20:38:33 Transfers INTIME
# 2142-05-05 11:46:32 Transfers INTIME
# 2144-07-01 04:13:59 Transfers INTIME
# 2144-07-01 05:19:39 Transfers INTIME
# OUTTIME Transfers OUTTIME
# 2142-05-04 20:38:33 Transfers OUTTIME
# 2142-05-05 11:46:32 Transfers OUTTIME
# None Transfers OUTTIME
# 2144-07-01 05:19:39 Transfers OUTTIME
# 2144-07-01 06:28:29 Transfers OUTTIME

# %% [markdown]
# ### Parameters used with apoc.periodic.iterate function
# Multiple parameters were attempted for the apoc.periodic.iterate function while building the time tree, noted below:
#
# |batchSize|parallel|iterateList|observed velocity of relationship creation|CPU notes|Java RAM usage|
# |:---|:---|:---|:---|:---|:---|
# |10|true|true|3500/second|all 12 CPUs at ~100% initially, then all dropped to ~25%|6.9GB|
# |100|true|true|22600/second (may be incorrect)|all 12 CPUs at ~100% initially, then all dropped to ~40-45%|7.6GB|
# |1000|true|true|11850/second|all 12 CPUs at ~100% initially, then all dropped to ~75%|8.1GB|
#
# Using parallell=false was also attempted, but this setting used only 1 CPU and was visibly slower than the other methods, so it was aborted.
#
# ### Size of the tree
# Prior to building time tree there were about 587,770,000 relationships in the database. After building the time tree there were 904,108,341 relationships in the database. The tree itself contained:
#
# |Label|Nodes Count|
# |:---|:---|
# |Days|55848|
# |Months|3314|
# |Years|311|
# |Time Tree root|1|
#
# The years spanned from year 1800 to year 2244, which is 444 years. As the table above demonstrates, only 311 of the possible 444 years actually appeared in timestamp data, which makes sense given the randomization scheme for shifting dates used during the anonymization process ([see here for details](https://mimic.physionet.org/mimicdata/time/)).
#
#
# The available disk space decreased by 149 GB after the time tree was created.

# %% [markdown]
# ## Performance Testing
# ---

# %% [markdown]
# ### Close the connection to the neo4j database

# %%
session.close()
